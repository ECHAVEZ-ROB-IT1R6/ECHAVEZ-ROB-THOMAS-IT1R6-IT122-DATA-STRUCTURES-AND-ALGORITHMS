# %%
print("Discuss your learnings on Chapter 1  time-frame 8:00 - 30:35. Minimum of 200 characters")
print("")
print("Chapter 1:Learnings are the following")
print("")
print("Algorithm is a sequence of computational steps. ")
print("Data structures is a way to store and organize data in the right order")
print("Interface is the set of operators that a structure of data supports.")
print("implementation is what gives the definitiion of the algorithms use in operation of data structure.")
print("There are three charcaters of Data Structures namely, correctness, Time complexity and space complexity.")
print("As a programmer it is very important that you implment an interface correctly.")
print("A programmer also must understand that time is important and it should be small as possible.")
print("Lastly, a programmer should have a little memory usage")
print("There are three execution time cases and these are:")
print("worst case are scenarios that takes the maximus time.")
print("Average case are the time cases as from the word itself average meaning it is average")
print("Best case is where you expect that it will take for example 20 seconds to run but it will only take 5 seconds")
print("In learning the data structures is very important because we will understand how to organize data.")
print("There are five applications of data structures and alogorithms and these are:")
print("Search, sort, insert, update, and delete")
print("In order to dully understand how data structures and algorithm works you need to learn the terminology.")
print("Algorithm has characteristics that needs to be followed.")
print("First is it needs to be unambigous meaning it must be clear.")
print("Second there must be input and output.")
print("Third is the most important because you need the number of steps to be finite meaning there is an ending.")
print("Fourth, the resources used must be feasible meaning available and reachable")
print("Lastly, an alogirthm must always be independent meaning you don't just make it for that sole purpose.")
# Out:
# Discuss your learnings on Chapter 1  time-frame 8:00 - 30:35. Minimum of 200 characters
#
# Chapter 1:Learnings are the following
#
# Algorithm is a sequence of computational steps.
# Data structures is a way to store and organize data in the right order
# Interface is the set of operators that a structure of data supports.
# implementation is what gives the definitiion of the algorithms use in operation of data structure.
# There are three charcaters of Data Structures namely, correctness, Time complexity and space complexity.
# As a programmer it is very important that you implment an interface correctly.
# A programmer also must understand that time is important and it should be small as possible.
# Lastly, a programmer should have a little memory usage
# There are three execution time cases and these are:
# worst case are scenarios that takes the maximus time.
# Average case are the time cases as from the word itself average meaning it is average
# ...

# %%
print("Discuss your learnings on Chapter 1  time-frame 35:00 - end. Minimum of 200 characters")
print("")
print("Chapter 1:Learnings are the following")
print("")
print("In algorithm complexity, I have learned about Time factor and space factor.")
print("Time factor means the measurement of time by counting the number of key operations.")
print("Space factor is that a space is measured by counting the memory space that is require from the algorithm")
print("I also learned about space complexity which is what represents the amount of memory space required in algorithm.")
print("Space complexity has a fixed part which this will space stores certain data and variables.")
print("It also has a variable part which is required by a variable whose size depends on the problem's size.")
print("There is also Time complexity where it represents the amount time that is required by the algorithm.")
print("Time requirement is often defined as a numerical function.")
print("Also, there is Algorithm analysis where it can be analyzed in two different stages.")
print("The Priori analysis is like the theoretical analysis of an algorithm.")
print("An algorithm's efficiency is measure if all factors are constant and no effect on the implementation.")
print("Next is the Posterior analysis where it is an emperical anaylysis of an algorithm.")
print("Actual statistics are and will be collected.")
print("The algorithm will be implemented using the programming language.")
print("The target will be executed on a target computer machine.")
# Out:
# Discuss your learnings on Chapter 1  time-frame 35:00 - end. Minimum of 200 characters
#
# Chapter 1:Learnings are the following
#
# In algorithm complexity, I have learned about Time factor and space factor.
# Time factor means the measurement of time by counting the number of key operations.
# Space factor is that a space is measured by counting the memory space that is require from the algorithm
# I also learned about space complexity which is what represents the amount of memory space required in algorithm.
# Space complexity has a fixed part which this will space stores certain data and variables.
# It also has a variable part which is required by a variable whose size depends on the problem's size.
# There is also Time complexity where it represents the amount time that is required by the algorithm.
# Time requirement is often defined as a numerical function.
# Also, there is Algorithm analysis where it can be analyzed in two different stages.
# ...

# %%
print("Discuss your learnings on Chapter 2  time-frame 5:00 - 9:00. Minimum of 200 characters")
print("")
print("Chapter 2:Learnings are the following")
print("")
print("I learned about the derived data types.")
print("These are data types that are implementation independent as they are known to be implemented one way or another.")
print("I believe that a derived data type is much more advance properties.")
print("They are built in combinations of primary and built in types.")
print("Derived data types have built in data types which are list, array, satck, queue")
print("I also learned about the basic operations which are datas in the data structure is processed by certain operations")
print("That is why a data cannot function if you do not operate it.")
print("We have different basic operations namely traversing, insertion, deletion, sorting and merging.")
print("Traversing is something moves or cross from one way to another.")
print("Insertion as from its word it means to insert.")
print("Deletion is to delete or remove an item permanently.")
print("Sorting is when you sort like arrange an item systematically.")
print("Lastly Merging which means to combine an item.")
print("I also learned that we need to bear in mind that we should always define data")
print("A data object has data types and that data types has built in and derived data type.")
print("Those data types should be operated or it won't function or run.")
print("And lastly, the teacher added update in one the basic operations where it means to bring something up to date")
# Out:
# Discuss your learnings on Chapter 2  time-frame 5:00 - 9:00. Minimum of 200 characters
#
# Chapter 2:Learnings are the following
#
# I learned about the derived data types.
# These are data types that are implementation independent as they are known to be implemented one way or another.
# I believe that a derived data type is much more advance properties.
# They are built in combinations of primary and built in types.
# Derived data types have built in data types which are list, array, satck, queue
# I also learned about the basic operations which are datas in the data structure is processed by certain operations
# That is why a data cannot function if you do not operate it.
# We have different basic operations namely traversing, insertion, deletion, sorting and merging.
# Traversing is something moves or cross from one way to another.
# Insertion as from its word it means to insert.
# Deletion is to delete or remove an item permanently.
# ...

# %%
print("Discuss your learnings on Chapter 3  time-frame 3:00 - 18:00. Minimum of 200 characters")
print("")
print("Chapter 3:Learnings are the following")
print("")
print("Arrays can be declared in a various space and in a different language")
print("The name of your array depends on how you name it")
print("Inside the curly braces are your values and when the elements in the index always starts with zero.")
print("All the elements in the curly braces are the size stand.")
print("Elements can be accessed by its index.")
print("The format in python programming will be defining its array name, next is the method and the typecode and then initializers.")
print("Typecode are codes use to define the types of values in the array.")
print("In coding an array you must first type from array import and then the asterisk symbol means all")
print("By using array you can be much faster.Instead of declaring it like A=1, B=2 you use array to save time.")
print("In order to access the element of an array is to call arrayName and the index you want to access.")
print("To use insertion, you need to call the arrayName and then the insert and specify the index where you want to insert.")
print("In python there is alaready a method called insert so it is easier.")
print("For deletion it is the same process but you ise the remove method instead of delete.")
print("In updating you need to call the arrayName and the index you need to update.")
# Out:
# Discuss your learnings on Chapter 3  time-frame 3:00 - 18:00. Minimum of 200 characters
#
# Chapter 3:Learnings are the following
#
# Arrays can be declared in a various space and in a different language
# The name of your array depends on how you name it
# Inside the curly braces are your values and when the elements in the index always starts with zero.
# All the elements in the curly braces are the size stand.
# Elements can be accessed by its index.
# The format in python programming will be defining its array name, next is the method and the typecode and then initializers.
# Typecode are codes use to define the types of values in the array.
# In coding an array you must first type from array import and then the asterisk symbol means all
# By using array you can be much faster.Instead of declaring it like A=1, B=2 you use array to save time.
# In order to access the element of an array is to call arrayName and the index you want to access.
# ...

# %%
from array import *

favoriteNumbers = array('i', [1,4,10,31,100,150])
favoriteNumbers.insert(3,24)
favoriteNumbers.remove(150)
favoriteNumbers[5] = 200
for x in favoriteNumbers:
    print(x)
# Out:
# 1
# 4
# 10
# 24
# 31
# 200
